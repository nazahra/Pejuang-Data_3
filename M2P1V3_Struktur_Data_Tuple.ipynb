# %% [markdown]
# ## Struktur Data Tuple

# %% [markdown]
# Tuple adalah jenis dari struktur data yang tidak dapat diubah elemennya. Umumnya Tuple digunakan untuk data yang bersifat sekali tulis dan dapat dieksekusi lebih cepat. Tuple didefinisikan dengan kurung dan elemen yang dipisahkan dengan koma.

# %%
# Contoh Tuple
T1 = (1, "dua", True, 1+2j)
print ("ini adalah Tuple", T1)
# Out:
# ini adalah Tuple (1, 'dua', True, (1+2j))

# %%
# Menampilkan tipe struktur data
type(T1)
# Out:
# tuple

# %% [markdown]
# **Latihan**

# %%
#Tuple 1
T1 = (3, "kita", False, 5+3j)
print ("ini adalah Tuple buatan saya", T1)
# Out:
# ini adalah Tuple buatan saya (3, 'kita', False, (5+3j))

# %% [markdown]
# **Sifat-sifat Tuple**

# %%
#Terurut/Ordered
T1[0:3]
# Out:
# (1, 'dua', True)

# %%
#Tibak bisa diganti/Immutable
T1[2] = "manusia"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-85e302ab13f0> in <module>()
#       1 #Tibak bisa diganti/Slicing
# ----> 2 T1[2] = "manusia"
#
# TypeError: 'tuple' object does not support item assignment

# %%
#Dapat diindeks/slicing
print("elemen kedua dari Tuple T1 adalah:", T1[2])
# Out:
# elemen kedua dari Tuple T1 adalah: True

# %%
#Dapat diizinkan duplikasi
T2 = (3, 2.4, True, 2.4)
T2
# Out:
# (3, 2.4, True, 2.4)

# %% [markdown]
# **Menggabungkan Tiple**

# %%
#Menggabungkan tuple
T3 = T1 + T2
T3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-480772dbd922> in <module>()
#       1 #Menggabungkan tuple
# ----> 2 T3 = T1 + T2
#       3 T3
#
# NameError: name 'T1' is not defined

# %% [markdown]
# **Latihan 2**

# %%
#Tuple 2
T2 = (15, 9.25, True, 9.25)
T2
# Out:
# (15, 9.25, True, 9.25)

# %%
#Gabungan Tuple
T3 = T1 + T2
T3
# Out:
# (3, 'kita', False, (5+3j), 15, 9.25, True, 9.25)
